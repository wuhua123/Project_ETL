# %%
#import libraries
#youtube_data has a class 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
from youtube_data import youtube_search

# %%
# create a search and loking at object we can work on 
#2018-12-18T18:49:45.000Z - Time format
#bitcoin = youtube_search("Bitcoin", publishedAfter="2018-12-01T00:00:00.000Z", publishedBefore="2018-12-16T00:00:00.000Z")
bitcoin = youtube_search("Bitcoin", publishedBefore="2018-12-01T04:52:42.000Z")
#bitcoin = youtube_search("Bitcoin", publishedAfter="2018-12-16T00:00:00.000Z")
bitcoin.keys()
# Out:
# []
# dict_keys(['tags', 'channelId', 'channelTitle', 'categoryId', 'title', 'videoId', 'viewCount', 'likeCount', 'dislikeCount', 'commentCount', 'favoriteCount', 'publishAt'])

# %%
#Retrieving view count data 
bitcoin['publishAt']

# Save date and time period of data for future use
time_df = pd.DataFrame(bitcoin['publishAt'])
time_df.to_csv("CSV_Files/bitcoin_youtube_time1_1.csv")

# %%
# dataframe
bitcoin_df = pd.DataFrame(data=bitcoin)
bitcoin_df.head()
# Out:
#                                                 tags  \
# 0  [how to trade bitcoin, is bitcoin dead, will b...
# 1  [blockchain, blockshow, coin, cointelegraph, c...
# 2  [Fast Money, CNBC, business news, finance stoc...
# 3  [Squawk Box U.S., CNBC, business news, finance...
# 4  [Squawk Box U.S., CNBC, business news, finance...
#
#                   channelId     channelTitle categoryId  \
# 0  UCVIOA9XqMtMUk8U-IF-dSYA         Forflies         27
# 1  UCRqBu-grVX1p97WaX4d-OuQ    Cointelegraph         25
# 2  UCrp_UI8XtuYfpiqluWLD7Lw  CNBC Television         25
# 3  UCrp_UI8XtuYfpiqluWLD7Lw  CNBC Television         25
# 4  UCrp_UI8XtuYfpiqluWLD7Lw  CNBC Television         25
#
#                                                title      videoId viewCount  \
# 0  The Bitcoin Selloff is About to Get Much Worse...  ipo9zBB_tIQ     59311
# 1         Bitcoin Collapse Explained | Cointelegraph  BFE3nZ9P1QQ    107342
# 2  Bitcoin is at the end of a distress cycle, say...  QUbtkMr7QBo     40828
# 3    Tom Lee cuts bitcoin year-end target to $15,000  Y-pX6GbRbwc    131390
# 4  Bitcoin won't have bottomed until 3K flat leve...  L5FbbVT98Zw    108705
#
#   likeCount dislikeCount commentCount favoriteCount                 publishAt
# 0       900          367          774             0  2018-11-25T15:00:06.000Z
# 1      1486          154          576             0  2018-11-22T22:21:02.000Z
# 2       387          121           []             0  2018-11-28T23:42:52.000Z
# 3       950          588         1361             0  2018-11-20T13:22:58.000Z
# 4       696          326         1026             0  2018-11-23T13:26:40.000Z

# %%
# arranging dateframe
bitcoin_arrangeview = bitcoin_df[['title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId', 'publishAt']]
bitcoin_arrangeview.columns = ['Title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId', 'publishAt']
bitcoin_arrangeview.head()
# Out:
#                                                Title viewCount  \
# 0  The Bitcoin Selloff is About to Get Much Worse...     59311
# 1         Bitcoin Collapse Explained | Cointelegraph    107342
# 2  Bitcoin is at the end of a distress cycle, say...     40828
# 3    Tom Lee cuts bitcoin year-end target to $15,000    131390
# 4  Bitcoin won't have bottomed until 3K flat leve...    108705
#
#       channelTitle commentCount likeCount dislikeCount  \
# 0         Forflies          774       900          367
# 1    Cointelegraph          576      1486          154
# 2  CNBC Television           []       387          121
# 3  CNBC Television         1361       950          588
# 4  CNBC Television         1026       696          326
#
#                                                 tags favoriteCount  \
# 0  [how to trade bitcoin, is bitcoin dead, will b...             0
# 1  [blockchain, blockshow, coin, cointelegraph, c...             0
# 2  [Fast Money, CNBC, business news, finance stoc...             0
# 3  [Squawk Box U.S., CNBC, business news, finance...             0
# 4  [Squawk Box U.S., CNBC, business news, finance...             0
#
#        videoId                 channelId categoryId                 publishAt
# 0  ipo9zBB_tIQ  UCVIOA9XqMtMUk8U-IF-dSYA         27  2018-11-25T15:00:06.000Z
# 1  BFE3nZ9P1QQ  UCRqBu-grVX1p97WaX4d-OuQ         25  2018-11-22T22:21:02.000Z
# 2  QUbtkMr7QBo  UCrp_UI8XtuYfpiqluWLD7Lw         25  2018-11-28T23:42:52.000Z
# 3  Y-pX6GbRbwc  UCrp_UI8XtuYfpiqluWLD7Lw         25  2018-11-20T13:22:58.000Z
# 4  L5FbbVT98Zw  UCrp_UI8XtuYfpiqluWLD7Lw         25  2018-11-23T13:26:40.000Z

# %%
#kickoff = [item.replace("'", "") for item in kickoff]
#for i in range(len(bitcoin_arrangeview['commentCount'])):
    #bitcoin_arrangeview.loc[i, 'commentCount'] = bitcoin_arrangeview.loc[i, 'commentCount'].replace('[]', '0') for item in bitcoin_arrangeview['commentCount']
#bitcoin_arrangeview.commentCount.replace('[]', 0)
#bitcoin_arrangeview['commentCount'] = bitcoin_arrangeview.commentCount.replace('[]', '0')
#print(bitcoin_arrangeview['commentCount'])

# %%
# Selecting the rows to convert into intergers from strings
numeric_dtype = ['viewCount','likeCount','dislikeCount','favoriteCount']

# %%
# loop to integers
for i in numeric_dtype:
        bitcoin_arrangeview[i] = bitcoin_df[i].astype(int)

# %%
new_topics_data_df = bitcoin_arrangeview[['channelTitle', 'Title', 'viewCount', 'likeCount', 'publishAt']]
new_topics_data_df.head(25)
# Out:
#                                         channelTitle  \
# 0                                           Forflies
# 1                                      Cointelegraph
# 2                                    CNBC Television
# 3                                    CNBC Television
# 4                                    CNBC Television
# 5   TechCashHouse - Best Bitcoin, Crypto, Money News
# 6                                The Modern Investor
# 7                                      Altcoin Daily
# 8                                               AMTV
# 9                              WHAT'S INSIDE? FAMILY
# 10                                      Austin Evans
# 11  TechCashHouse - Best Bitcoin, Crypto, Money News
# 12                                   CNBC Television
# 13                                   Alessio Rastani
# 14                                   Alessio Rastani
# 15                                           VINwiki
# 16                                   CNBC Television
# 17                                             LAHWF
# 18                                   CNBC Television
# 19                                     Altcoin Daily
# 20                                       Crypto Jebb
# 21                                     Altcoin Daily
# 22                                              AMTV
# 23                               The Modern Investor
# 24                                100thMonkeyChannel
#
#                                                 Title  viewCount  likeCount  \
# 42  2018-11-25T14:11:59.000Z
# 7   2018-11-11T14:00:04.000Z
# 23  2018-10-03T20:21:57.000Z
# 39  2018-11-27T12:18:06.000Z
# 38  2018-11-27T22:09:04.000Z
# 44  2018-11-19T21:08:23.000Z
# 5   2018-12-01T00:00:06.000Z
# 37  2018-11-25T00:32:08.000Z
# 29  2018-11-26T23:13:34.000Z
# 20  2018-11-27T16:28:39.000Z
# 33  2018-11-25T01:31:40.000Z
# 27  2018-11-26T13:39:21.000Z
# 48  2018-11-26T05:00:02.000Z
# 16  2018-08-15T18:47:55.000Z
# 47  2018-11-19T00:00:02.000Z
# 46  2018-11-29T23:21:33.000Z
# 34  2018-11-28T19:31:51.000Z
# 43  2018-11-15T05:00:00.000Z

# %%
# Add one column source to indicate the data source
new_topics_data_df['source'] = 'Youtube'

print(new_topics_data_df.dtypes)
print(new_topics_data_df.head())
# Out:
# channelTitle    object
# Title           object
# viewCount        int32
# likeCount        int32
# publishAt       object
# source          object
# dtype: object
#       channelTitle                                              Title  \
# 0         Forflies  The Bitcoin Selloff is About to Get Much Worse...
# 1    Cointelegraph         Bitcoin Collapse Explained | Cointelegraph
# 2  CNBC Television  Bitcoin is at the end of a distress cycle, say...
# 3  CNBC Television    Tom Lee cuts bitcoin year-end target to $15,000
# 4  CNBC Television  Bitcoin won't have bottomed until 3K flat leve...
#
#    viewCount  likeCount                 publishAt   source
# 0      59311        900  2018-11-25T15:00:06.000Z  Youtube
# 1     107342       1486  2018-11-22T22:21:02.000Z  Youtube
# 2      40828        387  2018-11-28T23:42:52.000Z  Youtube
# 3     131390        950  2018-11-20T13:22:58.000Z  Youtube
# 4     108705        696  2018-11-23T13:26:40.000Z  Youtube
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_topics_data_df.to_csv("CSV_Files/bitcoin_youtube3.csv", header=True)

# %%
# Strip off time part of datetime:
new_topics_data_df['publishAt'] = pd.to_datetime(new_topics_data_df['publishAt'])

for i in range(len(new_topics_data_df['publishAt'])):
    new_topics_data_df.loc[i, 'publishAt'] = new_topics_data_df.loc[i, 'publishAt'].date()
    
#print(new_topics_data_df['publishAt'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Convert datatime64 to string for column created:
new_topics_data_df['publishAt'] = new_topics_data_df['publishAt'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Convert pd int64 into int32 for column retweet and favorite_count:
# channelTitle	Title	viewCount	likeCount	publishAt
new_topics_data_df['viewCount'] = pd.Series(new_topics_data_df['viewCount'], dtype=str)
new_topics_data_df['likeCount'] = pd.Series(new_topics_data_df['likeCount'], dtype=str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# Replace NaN with None
new_topics_data_df = new_topics_data_df.where(pd.notnull(new_topics_data_df), None)

# %%
# Check data types    
new_topics_data_df.dtypes
# Out:
# channelTitle    object
# Title           object
# viewCount       object
# likeCount       object
# publishAt       object
# source          object
# dtype: object

# %%
# Dependencies
# ----------------------------------

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float, UnicodeText, Date, BigInteger

Base = declarative_base()

# %%
# Create Bitcoin_Youtube Classe: channelTitle	Title	viewCount	likeCount	publishAt
# ----------------------------------


class Bitcoin_Youtube(Base):
    __tablename__ = 'bitcoin_youtube'
    id = Column(Integer, primary_key=True)
    channelTitle = Column(String(200))
    Title = Column(UnicodeText)
    viewCount = Column(Integer)
    likeCount = Column(Integer)
    publishAt = Column(Date)
    source = Column(String(20))

# %%
# Create Database Connection
# ----------------------------------
# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

#engine = create_engine("mysql://k5xunpkmojyzse51:ifagg1gp7e2xyapi@ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/tq6h098h0ym00zp6")
engine = create_engine("mysql://root:Winter#1@127.0.0.1:3306/crypto_db")
conn = engine.connect()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
# Create (if not already in existence) the tables associated with our classes.
Base.metadata.create_all(engine)

# Use this to clear out the db
# ----------------------------------
# Base.metadata.drop_all(engine)

# %%
# Create a Session Object to Connect to DB
# ----------------------------------
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Add Records to the Appropriate DB
# ----------------------------------
# Use the SQL ALchemy methods to run simple "INSERT" statements using the class and object of Bitcoin_Youtube.
# channelTitle	Title	viewCount	likeCount	publishAt

for i in range(len(new_topics_data_df['publishAt'])):  
    one_bitcoin_youtube = Bitcoin_Youtube(channelTitle=new_topics_data_df.loc[i,'channelTitle'],
                                          Title=new_topics_data_df.loc[i,'Title'],
                                          viewCount=new_topics_data_df.loc[i,'viewCount'],
                                          likeCount=new_topics_data_df.loc[i,'likeCount'],
                                          publishAt=new_topics_data_df.loc[i,'publishAt'],
                                          source=new_topics_data_df.loc[i,'source'])
    session.add(one_bitcoin_youtube)
    session.commit()

# %%
# Query the Tables
# ----------------------------------
# Perform a simple query of the database
#dog_list = session.query(Dog)
#for doggy in dog_list:
#    print(doggy.name)

bitcoin_y_list = session.query(Bitcoin_Youtube)
for btc_youtube in bitcoin_y_list:
    print(btc_youtube.Title)
# Out:
# Bitcoin is DANGEROUSLY close to Capitulation! Plus XRP and Cardano Announcements!
# Someone Is Buying TONS of Bitcoin and It’s NOT Who You Think! The ONE Chart No One is Talking About!
# This Man calls the Future of Bitcoin since 2011 like an Oracle!
# JOHN MCAFEE’S New OPINION Of BITCOIN WILL BLOW YOUR MIND! Does He KNOW Something HUGE Is COMING?
# Bitcoin will SKYROCKET in weeks or Q1 2019
# BITCOIN MILLIONAIRE EXPLAINS MARKET CRASH AND NEXT PRICE TARGET $1,300!!
# TOM LEE’S CRAZY New OPINION Of BITCOIN WILL SERIOUSLY AMAZE YOU! Does He KNOW Something WE DON’T?
# Bitcoin miners shutting down world wide! Bitmain in trouble.
# Time Traveller's Prediction for Bitcoin Price 2019
# I'm DONE Buying Bitcoin
# Bitcoin on the verge of becoming worthless?
# Bitcoin In 2019 - My Prediction
# The Bitcoin Signal NOBODY is Watching Right Now
# “Bitcoin WILL RECOVER AMAZINGLY, DON’T SWEAT IT IN 2019” This GENIUS BTC SECRET Will BLOW YOUR MIND
# Why A NEW BITCOIN HIGH Is COMING In 2019, And WHY THIS EXPERT Is SO SURE - You NEED To HEAR THIS
# Why Bitcoin CANNOT Fall Under $3,000!!! 5 Predictions for $BTC 2019 | MASSIVE $XRP & Crypto Updates!
# Attention: Bitcoin Next Major Move Could Be LEGENDARY (Bitcoin Crash News Today)
# “Bitcoin Is ABOUT TO RECOVER In WAY NEVER SEEN For THIS REASON” TOM LEE Shares STARTLING New Secret
# Bitcoin Tumbles In Price, Set To Go Lower - What Is Happening To Crypto Markets?
# Can Bitcoin Reach $1 Million by 2020? -Realistically
# TIM DRAPER BITCOIN PREDICTION $250K BY 2022!! $10 TRILLION CRYPTO MKT CAP!
# Selling Bitcoin at a Coin Shop!
# What is Bitcoin?
# “You MUST Invest In Bitcoin Before 2019 For 3 KEY REASONS” - BTC Bull Tom Lee Tells MARKET SECRET
# I am still a long-term bitcoin believer, says the Crypto King
# How Low Will Bitcoin Go?
# Is the Drop in Bitcoin Really A False Breakout?
# I just bought a Lamborghini with Bitcoin
# Former PayPal CEO on why he thinks bitcoin is going to zero
# Chatting with an Expert on Bitcoin
# This Bitcoin millionaire who lives in tree house
# Warning: I Think Bitcoin Is Going Under 3K...Here Is Why? [Altcoins I Bought]
# If You're Considering Leaving Bitcoin, Watch This Video.
# WARNING: If you hold Bitcoin BE READY! [Cryptocurrency Perspective]
# CNBC HOST CLAIMS BITCOIN WILL GO TO ZERO IN 2018... TOTAL COLLAPSE!!
# The Bitcoin 1% - How Much Do You Need To Be "Bitcoin Rich"?
# Bitcoin: Beyond The Bubble - Full Documentary
# Bitcoin's NEXT Downside Target is...
# An Important Message to All Bitcoin HODLers!
# Bitcoin will end down at 85 percent of previous highs, says expert
# This Bitcoin War Has Only Just Begun...
# Long, dark winter ahead for crypto, says bitcoin oracle Vinny Lingham
# Bitcoin Breaks the Floor... How Bad is This?
# Bitcoin and Crypto Market CRASH - Will History Repeat on Nov 15th?
# BITCOIN TO $1500? Top Bloomberg analyst reveals shocking data! [Interview]
# Bitcoin Down 40% in 10 Days | What I'm Doing
# Bitcoin Run - Will It Continue? - BTC Analysis
# My Target Bitcoin Buy-In Price
# Announcements: SEC Bitcoin ETF Approval, BAKKT, and Nasdaq's Launching Crypto 2.0 [Consensus Invest]
# Bitcoin CRASHING BELOW $4,000!! | The Never Ending BLOODBATH! | Key Support BROKEN!
# A SCARY REALITY OF BITCOIN THAT NO ONE WANTS TO TALK ABOUT... - BTC/CRYPTOCURRENCY TRADING ANALYSIS
# Bitcoin down almost 80 percent since 2017 peak
# John McAfee drop Bitcoin Price Predictions that may shock you
# The Man Who Put Everything He Owns Into Bitcoin | Moving Upstream
# BITCOIN UNDER $1,000 WOULD BE CAPITULATION, I’LL MORTGAGE MY HOUSE!!
# “Bitcoin’s PRICE Will SOON ROCKET, Here’s The REASON WHY” - BTC Genius Explains BULL MARKET RETURN
# BITCOIN CRASHING BELOW $5,000!! | BTC Has NEVER Been This Oversold In RSI, Bounce IMMINENT??
# Bitcoin Drops to SECOND Downside Target... What Does it Mean?
# I come to bury bitcoin, says UBS' global chief economist
# “Bitcoin To RECOVER MASSIVELY, HISTORIC Price Indicators REVEAL” - BTC Bull Tom Lee Calms Investors
# “DON’T PANIC If Bitcoin Falls; BTC To Recover INSANELY” - BTC Guru John McAfee Explains KEY Strategy
# Is Bitcoin the Future of Money? Peter Schiff vs. Erik Voorhees
